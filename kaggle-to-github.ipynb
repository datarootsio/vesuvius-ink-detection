# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
GITHUB_TOKEN = user_secrets.get_secret("github_token")

# %%
# !git clone https://{GITHUB_TOKEN}@vesuvius-challenge.git

# %%
print(f"https://{GITHUB_TOKEN}@vesuvius-challenge.git")

# %%
# add path path in the system
import sys
sys.path.append("vesuvius-challenge")

# %%
import os

# %%
# change working directory
os.chdir("/kaggle/input/")

# %%
# !git clone https://{GITHUB_TOKEN}@vesuvius-challenge.git
